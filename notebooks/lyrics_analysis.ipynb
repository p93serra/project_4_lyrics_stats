# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/songs_lyrics.csv")

# %%
df[df.year == 2000]
# Out:
#             name       artist_1 artist_2  \
# 0   Walking Away    Craig David      NaN
# 31    What It Is  Mark Knopfler      NaN
#
#                                      uri  year  popularity  explicit  \
# 0   spotify:track:3R7fjB38qajI6JR69y5k4e  2000          60     False
# 31  spotify:track:65f8Ca4HbZCMLhpZPTHW4O  2000          60     False
#
#     duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 0        204867         0.596   0.686    9    -6.371     0       0.0345
# 31       295893         0.624   0.682    6    -7.274     0       0.0302
#
#     acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.196             0.000     0.121    0.815  172.835
# 31         0.615             0.252     0.288    0.432  122.084
#
#                                          words_lyrics
# 0   ['something', 'baby', 'listen', 'fight', 'wann...
# 31  ['search', 'could', 'warm', 'stick', 'moon', '...

# %%
df['decade'] = pd.cut(x=df['year'], bins=[1949, 1959, 1969, 1979, 1989, 1999, 2009, 2019, 2029], labels=['50s', '60s', '70s', '80s', '90s', '00s', '10s', '20s'])

# %%
df.head()
# Out:
#                                                 name             artist_1  \
# 0                                       Walking Away          Craig David
# 1                   Hotel California - 2013 Remaster               Eagles
# 2                                        I'm On Fire    Bruce Springsteen
# 3                                          D.A.N.C.E              Justice
# 4  White & Nerdy (Parody of "Ridin'" by Chamillio...  "Weird Al" Yankovic
#
#   artist_2                                   uri  year  popularity  explicit  \
# 0      NaN  spotify:track:3R7fjB38qajI6JR69y5k4e  2000          60     False
# 1      NaN  spotify:track:40riOy7x9W7GXjyGp4pjAv  1976          81     False
# 2      NaN  spotify:track:3PzsbWSQdLCKDLxn7YZfkM  1984          73     False
# 3      NaN  spotify:track:33yAEqzKXexYM3WlOYtTfQ  2007          63     False
# 4      NaN  spotify:track:60R2v9lheAu3lwZwAFxMZK  2006          53     False
#
# ...

# %%
df.groupby('decade')['explicit'].value_counts()
# Out:
# decade  explicit
# 50s     False         2
# 60s     False         2
# 70s     False         4
# 80s     False         4
# 90s     False         8
#         True          1
# 00s     False        21
#         True          1
# 10s     False       104
#         True          6
# 20s     False        11
#         True          2
# Name: explicit, dtype: int64
